# %% [markdown]
# # Reading a file and basic data types

# %%
import openpyxl
from openpyxl import Workbook

# get workbook object; the data_only option captures the current value of any formulae
# Your file should be in the same directory as this code, OR you need to provide the FULL path to that file, not just it's name
wb = openpyxl.load_workbook('pyxl_demo_pyohio.xlsx', data_only= True)

# %% [markdown]
# # Workbook vs Worksheet vs "spreadsheet" vs "tab"

# %% [markdown]
# # Workbooks

# %%
dir(wb)
# Out:
# ['_Workbook__write_only',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_active_sheet_index',
#  '_add_sheet',
#  '_alignments',
#  '_borders',
#  '_cell_styles',
#  '_colors',
#  '_data_only',
#  '_differential_styles',
#  '_external_links',
#  '_fills',
#  '_fonts',
#  '_keep_links',
#  '_named_styles',
#  '_number_formats',
#  '_protections',
#  '_read_only',
#  '_setup_styles',
#  '_sheets',
#  '_table_styles',
#  'active',
#  'add_named_range',
#  'add_named_style',
#  'chartsheets',
#  'close',
#  'code_name',
#  'copy_worksheet',
# ...

# %%
print(wb.sheetnames)
# Out:
# ['simple_read', 'simple_write', 'visual_read', 'visual_write', 'japan_spending', 'clean_data', 'KPop_draft_roster']

# %% [markdown]
# # Worksheets

# %%
demo_worksheet = wb.get_sheet_by_name("clean_data")

# %%
dir(demo_worksheet)
# Out:
# ['BREAK_COLUMN',
#  'BREAK_NONE',
#  'BREAK_ROW',
#  'HeaderFooter',
#  'ORIENTATION_LANDSCAPE',
#  'ORIENTATION_PORTRAIT',
#  'PAPERSIZE_A3',
#  'PAPERSIZE_A4',
#  'PAPERSIZE_A4_SMALL',
#  'PAPERSIZE_A5',
#  'PAPERSIZE_EXECUTIVE',
#  'PAPERSIZE_LEDGER',
#  'PAPERSIZE_LEGAL',
#  'PAPERSIZE_LETTER',
#  'PAPERSIZE_LETTER_SMALL',
#  'PAPERSIZE_STATEMENT',
#  'PAPERSIZE_TABLOID',
#  'SHEETSTATE_HIDDEN',
#  'SHEETSTATE_VERYHIDDEN',
#  'SHEETSTATE_VISIBLE',
#  '_WorkbookChild__parent',
#  '_WorkbookChild__title',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
# ...

# %% [markdown]
# # Rows

# %%
demo_worksheet.rows
# Out:
# <generator object Worksheet._cells_by_row at 0x11395d3b8>

# %% [markdown]
# ## Generator vs List or Tuple

# %%
from pprint import pprint
for row in demo_worksheet.rows:
    print(type(row))
    pprint(row, indent = 4)
# Out:
# <class 'tuple'>
# (   <Cell 'clean_data'.A1>,
#     <Cell 'clean_data'.B1>,
#     <Cell 'clean_data'.C1>,
#     <Cell 'clean_data'.D1>,
#     <Cell 'clean_data'.E1>,
#     <Cell 'clean_data'.F1>,
#     <Cell 'clean_data'.G1>,
#     <Cell 'clean_data'.H1>)
# <class 'tuple'>
# (   <Cell 'clean_data'.A2>,
#     <Cell 'clean_data'.B2>,
#     <Cell 'clean_data'.C2>,
#     <Cell 'clean_data'.D2>,
#     <Cell 'clean_data'.E2>,
#     <Cell 'clean_data'.F2>,
#     <Cell 'clean_data'.G2>,
#     <Cell 'clean_data'.H2>)
# <class 'tuple'>
# (   <Cell 'clean_data'.A3>,
#     <Cell 'clean_data'.B3>,
#     <Cell 'clean_data'.C3>,
#     <Cell 'clean_data'.D3>,
#     <Cell 'clean_data'.E3>,
#     <Cell 'clean_data'.F3>,
#     <Cell 'clean_data'.G3>,
#     <Cell 'clean_data'.H3>)
# <class 'tuple'>
# (   <Cell 'clean_data'.A4>,
#     <Cell 'clean_data'.B4>,
#     <Cell 'clean_data'.C4>,
#     <Cell 'clean_data'.D4>,
#     <Cell 'clean_data'.E4>,
#     <Cell 'clean_data'.F4>,
# ...

# %% [markdown]
# # Cells

# %%
for cell in next(demo_worksheet.rows):
    print("Cell {0}{1}".format(cell.column, cell.row))
    print(cell)
    print(type(cell))
    print(cell.value)
    print()
# Out:
# Cell A1
# <Cell 'clean_data'.A1>
# <class 'openpyxl.cell.cell.Cell'>
# employee_num
#
# Cell B1
# <Cell 'clean_data'.B1>
# <class 'openpyxl.cell.cell.Cell'>
# cost_center
#
# Cell C1
# <Cell 'clean_data'.C1>
# <class 'openpyxl.cell.cell.Cell'>
# division
#
# Cell D1
# <Cell 'clean_data'.D1>
# <class 'openpyxl.cell.cell.Cell'>
# Manager
#
# Cell E1
# <Cell 'clean_data'.E1>
# <class 'openpyxl.cell.cell.Cell'>
# date_worked
#
# Cell F1
# <Cell 'clean_data'.F1>
# <class 'openpyxl.cell.cell.Cell'>
# Employee Name
#
# Cell G1
# <Cell 'clean_data'.G1>
# <class 'openpyxl.cell.cell.Cell'>
# hours_worked
#
# Cell H1
# <Cell 'clean_data'.H1>
# <class 'openpyxl.cell.cell.Cell'>
# project

# %% [markdown]
# # Cell Values and Types

# %%
print(demo_worksheet['e1'].value ,"|*|", type(demo_worksheet['e1'].value))
print(demo_worksheet["e2"].value,"|*|", type(demo_worksheet["e2"].value))
# Out:
# date_worked |*| <class 'str'>
# 2017-06-12 00:00:00 |*| <class 'datetime.datetime'>

# %%
demo_worksheet['e1'].value, demo_worksheet['e2'].value
# Out:
# ('date_worked', datetime.datetime(2017, 6, 12, 0, 0))

# %% [markdown]
# # Cell Attributes: Why's There A "Cell" Object?

# %%
dir(demo_worksheet["e2"])
# Out:
# ['ERROR_CODES',
#  'TYPE_BOOL',
#  'TYPE_ERROR',
#  'TYPE_FORMULA',
#  'TYPE_FORMULA_CACHE_STRING',
#  'TYPE_INLINE',
#  'TYPE_NULL',
#  'TYPE_NUMERIC',
#  'TYPE_STRING',
#  'VALID_TYPES',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_bind_value',
#  '_cast_datetime',
#  '_cast_numeric',
#  '_cast_percentage',
#  '_cast_time',
#  '_comment',
#  '_hyperlink',
#  '_infer_value',
#  '_style',
#  '_value',
#  'alignment',
#  'anchor',
#  'base_date',
#  'border',
#  'check_error',
#  'check_string',
#  'col_idx',
#  'column',
#  'comment',
#  'coordinate',
#  'data_type',
#  'encoding',
#  'fill',
#  'font',
#  'guess_types',
# ...

# %% [markdown]
# # Cell Styles

# %%
print(demo_worksheet["e2"].font.name)
print("*************")
print(demo_worksheet["e2"].font.color)
print("*************")
print(demo_worksheet["e2"].fill.bgColor)
print("*************")
print(demo_worksheet["e2"].border)
# Out:
# Arial
# *************
# <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='FF000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'
# *************
# <openpyxl.styles.colors.Color object>
# Parameters:
# rgb='00000000', indexed=None, auto=None, theme=None, tint=0.0, type='rgb'
# *************
# <openpyxl.styles.borders.Border object>
# Parameters:
# outline=True, diagonalUp=False, diagonalDown=False, start=None, end=None, left=<openpyxl.styles.borders.Side object>
# Parameters:
# style=None, color=None, right=<openpyxl.styles.borders.Side object>
# Parameters:
# style=None, color=None, top=<openpyxl.styles.borders.Side object>
# Parameters:
# style=None, color=None, bottom=<openpyxl.styles.borders.Side object>
# Parameters:
# style=None, color=None, diagonal=<openpyxl.styles.borders.Side object>
# Parameters:
# style=None, color=None, vertical=None, horizontal=None

# %% [markdown]
# ## I don't have time to demo, but styles are readable AND writeable.
#
# ## Making beautiful spreadsheets has been left as an exercise for the viewer.

# %% [markdown]
# # Example 1: Aggregate Time Sheet Info

# %% [markdown]
# ## Creating a "list" of employees

# %% [markdown]
# ### Set Comprehension vs For Loop

# %%
employee_ids2 = set()
for row in demo_worksheet.rows:
    if row[0].value != 'employee_num':
        employee_ids2.add(row[0].value)

# %%
print(employee_ids2)
# Out:
# {899591, 811272, 810761, 1098762, 897932, 814863, 820239, 832272, 825881, 906780, 1081500, 1090593, 820001, 1099812, 826917, 1101478, 1098279, 826924, 801836, 1100974, 1099700, 1075893, 801717, 894901, 1078455, 810425, 849079, 1079484, 806974, 826693, 899913, 806092, 897869, 811216, 830291, 1074010, 849758, 1083873, 831075, 849380, 1063013, 807275, 821100, 815346, 806771, 820596, 1102073, 841596, 1106301}

# %%
employee_ids1 = {row[0].value for row in demo_worksheet.rows if row[0].value != 'employee_num'}

# %%
print(employee_ids1)
# Out:
# {899591, 811272, 810761, 1098762, 897932, 814863, 820239, 832272, 825881, 906780, 1081500, 1090593, 820001, 1099812, 826917, 1101478, 1098279, 826924, 801836, 1100974, 1099700, 1075893, 801717, 894901, 1078455, 810425, 849079, 1079484, 806974, 826693, 899913, 806092, 897869, 811216, 830291, 1074010, 849758, 1083873, 831075, 849380, 1063013, 807275, 821100, 815346, 806771, 820596, 1102073, 841596, 1106301}

# %% [markdown]
# # Aggregation: Dictionary

# %%
employee_aggregate = {}
for employee in employee_ids1:
    hours = [row[6].value for row in demo_worksheet.rows if employee == row[0].value]
    cost_center = {row[1].value for row in demo_worksheet.rows if employee == row[0].value}
    division = {str(row[2].value) for row in demo_worksheet.rows if employee == row[0].value}
    manager = {row[3].value for row in demo_worksheet.rows if employee == row[0].value}
    
    assert len(cost_center) == len(division) == len(manager) == 1
    
    employee_aggregate[employee]={
        "hours": sum(hours),
        "cost_center": list(cost_center)[0],
        "division": list(division)[0],
        "manager": list(manager)[0]
    }

# %%
pprint(employee_aggregate, indent = 4)
# Out:
# {   801717: {   'cost_center': '55099',
#                 'division': '1000',
#                 'hours': 49,
#                 'manager': 'ffirs'},
#     801836: {   'cost_center': '55099',
#                 'division': '1000',
#                 'hours': 8,
#                 'manager': 'ffirs'},
#     806092: {   'cost_center': '55335',
#                 'division': '1000',
#                 'hours': 201.5,
#                 'manager': 'ffirs'},
#     806771: {   'cost_center': '55221',
#                 'division': '1000',
#                 'hours': 100,
#                 'manager': 'dirsa'},
#     806974: {   'cost_center': '55099',
#                 'division': '1000',
#                 'hours': 23.5,
#                 'manager': 'ffirs'},
#     807275: {   'cost_center': '55099',
#                 'division': '1000',
#                 'hours': 18,
#                 'manager': 'ffirs'},
#     810425: {   'cost_center': '55099',
#                 'division': '1000',
# ...

# %%
len(employee_aggregate)
# Out:
# 49

# %% [markdown]
# # Writing your Python Results To A Spreadsheet

# %%
output_book = Workbook() #OpenPyXL object
output_sheet = output_book.create_sheet("Aggregate Time",0)

# %%
output_book

# %% [markdown]
# # Building the Output Header: Specific Cell References

# %%
header = [
    demo_worksheet["A1"].value,
    demo_worksheet["B1"].value,
    demo_worksheet["C1"].value,
    demo_worksheet["D1"].value,
    demo_worksheet["G1"].value
]

# %%
print(header)
# Out:
# ['employee_num', 'cost_center', 'division', 'Manager', 'hours_worked']

# %%
output_data = []
output_data.append(header)

for emp in employee_aggregate: #iterating over dictionary keys
    new_row = []
    new_row.append(emp)
    new_row.append(employee_aggregate[emp]['cost_center'])
    new_row.append(employee_aggregate[emp]['division'])
    new_row.append(employee_aggregate[emp]['manager'])
    new_row.append(employee_aggregate[emp]['hours'])
    output_data.append(new_row)

# Adding 1 because spreadsheets count from 1, not 0
for row in output_data:
    rowIn = output_data.index(row)
    for col in range(len(output_data[0])):
        output_sheet.cell(row = rowIn+1, column = col+1).value = output_data[rowIn][col]

# %%
pprint(output_data, indent=4)
# Out:
# [   ['employee_num', 'cost_center', 'division', 'Manager', 'hours_worked'],
#     [899591, '52P02', '1000', 'dirsa', 160],
#     [811272, '52P10', '1000', 'dirsa', 28.5],
#     [810761, '55335', '1000', 'ffirs', 50],
#     [1098762, '52P04', '1000', 'dirsa', 160],
#     [897932, '55308', '1000', 'nahan', 139],
#     [814863, '61101', '1000', 'nzali', 156.0],
#     [820239, '61101', '1000', 'nzali', 75.0],
#     [832272, '52P01', '1000', 'dirsa', 169.5],
#     [825881, '52P02', '1000', 'dirsa', 133],
#     [906780, '52P04', '1000', 'dirsa', 111],
#     [1081500, '52P08', '1000', 'dirsa', 143],
#     [1090593, '52P08', '1000', 'dirsa', 20],
#     [820001, '52P04', '1000', 'dirsa', 156],
#     [1099812, '55221', '1000', 'dirsa', 101],
#     [826917, '52P04', '1000', 'dirsa', 168],
#     [1101478, '52P04', '1000', 'dirsa', 105.5],
#     [1098279, '55221', '1000', 'dirsa', 53.0],
#     [826924, '55221', '1000', 'dirsa', 134.5],
#     [801836, '55099', '1000', 'ffirs', 8],
# ...

# %%
output_book.save (filename = "done_pyohio.xlsx")

# %% [markdown]
# # Imagine 10-100x the amount of data or processing frequency

# %% [markdown]
# # How we use JSON at work

# %%
import json
with open("aggregate_time.json", 'w') as f:
    json.dump(employee_aggregate, f, sort_keys=True, indent=4)

# %%
ls -alt
# Out:
# total 2768
# -rw-r--r--   1 kojoidrissa  staff    6495 Jul 29 20:05 aggregate_time.json
# -rw-r--r--   1 kojoidrissa  staff    6601 Jul 29 20:05 done_pyohio.xlsx
# drwxr-xr-x  15 kojoidrissa  staff     510 Jul 29 20:05 ./
# -rw-r--r--   1 kojoidrissa  staff  379091 Jul 29 20:05 pyohio-2017.ipynb
# -rw-r--r--   1 kojoidrissa  staff     103 Jul 29 19:57 README.rst
# drwxr-xr-x  13 kojoidrissa  staff     442 Jul 29 19:54 .git/
# -rw-r--r--   1 kojoidrissa  staff    3164 Jul 29 19:51 pyohio-2017_python_spreadsheets.rst
# -rw-r--r--@  1 kojoidrissa  staff   49509 Jul 29 19:31 pyohio_2017-07.pdf
# -rw-r--r--@  1 kojoidrissa  staff  829012 Jul 29 18:41 pyohio_2017-07.key
# -rw-r--r--   1 kojoidrissa  staff   45254 Jul 29 09:42 pyxl_demo_pyohio.xlsx
# -rw-r--r--   1 kojoidrissa  staff    7750 Jul 29 09:42 done_pyohio.xlsx.old
# -rw-r--r--   1 kojoidrissa  staff    6495 Jul 29 01:53 aggregate_time.json.old
# -rw-r--r--   1 kojoidrissa  staff   60806 Jul 24 20:11 pyxl_demo_pyohio.ods
# ...

# %% [markdown]
# # I have BAD news and GOOD news...
